# %%
import numpy as np

# %%
# Step 1: Define the Dataset
data = [([1, 2], 0), ([3, 4], 1)]  # Data points with their respective classes
num_features = 2  # Number of features in each data point
num_classes = 2   # Number of classes

# %%
# Initialize theta with small random values
np.random.seed(0)
theta = np.random.randn(num_classes, num_features) * 0.01
print("Initial theta:\n", theta)
# Out:
# Initial theta:
#  [[0.01764052 0.00400157]
#  [0.00978738 0.02240893]]

# %%
# Define the log_sum_exp function
def log_sum_exp(X, theta):
    """
    Compute log(sum(exp(X.dot(theta))))
    X is a single data point (1D array), theta is the weight matrix.
    """
    exp_term = np.exp(X.dot(theta))  # Compute exp(X.dot(theta))
    sum_exp = np.sum(exp_term)  # Compute the sum of exponentials
    log_sum = np.log(sum_exp)  # Compute the log of the sum
    print(f"X={X}, theta=\n{theta}")
    print(f"exp_term:\n{exp_term}")
    print(f"sum_exp: {sum_exp}")
    print(f"log_sum: {log_sum}")
    return log_sum

# %%
# Loss function using the expression from the figure
def loss_function(data, theta):
    """
    Calculate the loss using the given dataset and the theta values.
    """
    loss = 0
    for X, c in data:
        X = np.array(X)  # Convert to numpy array
        theta_c = theta[c]  # Get the weights for the correct class
        loss_contrib = X.dot(theta_c) - log_sum_exp(X, theta)
        print(f"X={X}, class={c}")
        print(f"theta_c:\n{theta_c}")
        print(f"loss_contrib: {loss_contrib}")
        loss += loss_contrib
    print(f"Total loss: {loss}")
    return loss  # Return the negative log-likelihood as a scalar

# %%
# Gradient calculation using the expression from the figure
def gradient(data, theta):
    """
    Calculate the gradient of the loss function with respect to theta.
    """
    grad = np.zeros_like(theta)  # Initialize gradient with zeros
    for X, c in data:
        X = np.array(X)  # Convert to numpy array
        exp_theta = np.exp(X.dot(theta))  # Compute exp(X.dot(theta)) for all classes
        sum_exp_theta = np.sum(exp_theta)  # Compute the sum of exponentials for normalization
        prob = exp_theta / sum_exp_theta  # p(y | X, theta)
        print(f"X={X}")
        print(f"exp_theta:\n{exp_theta}")
        print(f"sum_exp_theta: {sum_exp_theta}")
        print(f"prob:\n{prob}")
        
        for a in range(num_classes):
            indicator = int(a == c)  # Indicator function I(a = c)
            grad_contrib = X * (indicator - prob[a])  # Gradient update for class 'a'
            print(f"Class {a}")
            print(f"indicator: {indicator}")
            print(f"grad_contrib:\n{grad_contrib}")
            grad[a] += grad_contrib
            print(f"grad[{a}] after update:\n{grad[a]}")
    print(f"Gradient:\n{grad}")
    return grad  # Return negative gradient

# %%
# Implement Gradient Descent
def gradient_descent(data, theta, learning_rate=0.1, iterations=100):
    """
    Perform gradient descent to optimize theta.
    """
    for i in range(iterations):
        grad = gradient(data, theta)  # Compute gradient
        theta -= learning_rate * grad  # Update theta
        loss = loss_function(data, theta)  # Compute loss
        print(f"Iteration {i}")
        print(f"Loss: {loss:.4f}")
        print(f"Gradient:\n{grad}")
        print(f"Updated theta:\n{theta}")
    return theta

# %%
# Run Gradient Descent
theta_final = gradient_descent(data, theta, learning_rate=0.1, iterations=100)
print("Final Parameters:\n", theta_final)
# Out:
# X=[1 2]
# exp_theta:
# [1.03791644 1.05003074]
# sum_exp_theta: 2.087947178643546
# prob:
# [0.49709899 0.50290101]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50290101 1.00580201]
# grad[0] after update:
# [0.50290101 1.00580201]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50290101 -1.00580201]
# grad[1] after update:
# [-0.50290101 -1.00580201]
# X=[3 4]
# exp_theta:
# [1.09644277 1.10698538]
# sum_exp_theta: 2.203428142316842
# prob:
# [0.49760768 0.50239232]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.49282304 -1.99043072]
# grad[0] after update:
# [-0.98992203 -0.98462871]
# Class 1
# indicator: 1
# grad_contrib:
# [1.49282304 1.99043072]
# grad[1] after update:
# [0.98992203 0.98462871]
# Gradient:
# [[-0.98992203 -0.98462871]
#  [ 0.98992203  0.98462871]]
# X=[1 2], theta=
# [[ 0.11663273  0.10246444]
#  [-0.08920482 -0.07605394]]
# exp_term:
# [0.94009258 0.95156866]
# sum_exp: 1.8916612395114658
# log_sum: 0.6374554057145182
# X=[1 2], class=0
# theta_c:
# [0.11663273 0.10246444]
# loss_contrib: -0.31589379332603645
# X=[3 4], theta=
# [[ 0.11663273  0.10246444]
#  [-0.08920482 -0.07605394]]
# exp_term:
# [0.99310278 1.00318263]
# sum_exp: 1.9962854095046383
# log_sum: 0.6912881584008584
# X=[3 4], class=1
# theta_c:
# [-0.08920482 -0.07605394]
# loss_contrib: -1.2631183837557955
# Total loss: -1.579012177081832
# Iteration 0
# Loss: -1.5790
# Gradient:
# [[-0.98992203 -0.98462871]
#  [ 0.98992203  0.98462871]]
# Updated theta:
# [[ 0.11663273  0.10246444]
#  [-0.08920482 -0.07605394]]
# X=[1 2]
# exp_theta:
# [0.94009258 0.95156866]
# sum_exp_theta: 1.8916612395114658
# prob:
# [0.49696667 0.50303333]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50303333 1.00606667]
# grad[0] after update:
# [0.50303333 1.00606667]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50303333 -1.00606667]
# grad[1] after update:
# [-0.50303333 -1.00606667]
# X=[3 4]
# exp_theta:
# [0.99310278 1.00318263]
# sum_exp_theta: 1.9962854095046383
# prob:
# [0.49747535 0.50252465]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.49242605 -1.9899014 ]
# grad[0] after update:
# [-0.98939271 -0.98383473]
# Class 1
# indicator: 1
# grad_contrib:
# [1.49242605 1.9899014 ]
# grad[1] after update:
# [0.98939271 0.98383473]
# Gradient:
# [[-0.98939271 -0.98383473]
#  [ 0.98939271  0.98383473]]
# X=[1 2], theta=
# [[ 0.215572    0.20084792]
#  [-0.18814409 -0.17443741]]
# exp_term:
# [0.85153371 0.86240791]
# sum_exp: 1.7139416183989518
# log_sum: 0.5387957579845982
# X=[1 2], class=0
# theta_c:
# [0.215572   0.20084792]
# loss_contrib: 0.07847207197437511
# X=[3 4], theta=
# [[ 0.215572    0.20084792]
#  [-0.18814409 -0.17443741]]
# exp_term:
# [0.89955023 0.90918571]
# sum_exp: 1.80873594422604
# log_sum: 0.5926282279456857
# X=[3 4], class=1
# theta_c:
# [-0.18814409 -0.17443741]
# loss_contrib: -1.8548101599305862
# Total loss: -1.7763380879562112
# Iteration 1
# Loss: -1.7763
# Gradient:
# [[-0.98939271 -0.98383473]
#  [ 0.98939271  0.98383473]]
# Updated theta:
# [[ 0.215572    0.20084792]
#  [-0.18814409 -0.17443741]]
# X=[1 2]
# exp_theta:
# [0.85153371 0.86240791]
# sum_exp_theta: 1.7139416183989518
# prob:
# [0.49682772 0.50317228]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50317228 1.00634456]
# grad[0] after update:
# [0.50317228 1.00634456]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50317228 -1.00634456]
# grad[1] after update:
# [-0.50317228 -1.00634456]
# X=[3 4]
# exp_theta:
# [0.89955023 0.90918571]
# sum_exp_theta: 1.80873594422604
# prob:
# [0.4973364 0.5026636]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.49200921 -1.98934562]
# grad[0] after update:
# [-0.98883693 -0.98300106]
# Class 1
# indicator: 1
# grad_contrib:
# [1.49200921 1.98934562]
# grad[1] after update:
# [0.98883693 0.98300106]
# Gradient:
# [[-0.98883693 -0.98300106]
#  [ 0.98883693  0.98300106]]
# X=[1 2], theta=
# [[ 0.31445569  0.29914802]
#  [-0.28702779 -0.27273752]]
# exp_term:
# [0.77136016 0.78166657]
# sum_exp: 1.5530267244387201
# log_sum: 0.440205752285534
# X=[1 2], class=0
# theta_c:
# [0.31445569 0.29914802]
# loss_contrib: 0.4725459826557758
# X=[3 4], theta=
# [[ 0.31445569  0.29914802]
#  [-0.28702779 -0.27273752]]
# exp_term:
# [0.81485583 0.82406489]
# sum_exp: 1.6389207163168162
# log_sum: 0.4940379253865562
# X=[3 4], class=1
# theta_c:
# [-0.28702779 -0.27273752]
# loss_contrib: -2.446071360637805
# Total loss: -1.973525377982029
# Iteration 2
# Loss: -1.9735
# Gradient:
# [[-0.98883693 -0.98300106]
#  [ 0.98883693  0.98300106]]
# Updated theta:
# [[ 0.31445569  0.29914802]
#  [-0.28702779 -0.27273752]]
# X=[1 2]
# exp_theta:
# [0.77136016 0.78166657]
# sum_exp_theta: 1.5530267244387201
# prob:
# [0.49668183 0.50331817]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50331817 1.00663634]
# grad[0] after update:
# [0.50331817 1.00663634]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50331817 -1.00663634]
# grad[1] after update:
# [-0.50331817 -1.00663634]
# X=[3 4]
# exp_theta:
# [0.81485583 0.82406489]
# sum_exp_theta: 1.6389207163168162
# prob:
# [0.49719051 0.50280949]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.49157153 -1.98876205]
# grad[0] after update:
# [-0.98825336 -0.98212571]
# Class 1
# indicator: 1
# grad_contrib:
# [1.49157153 1.98876205]
# grad[1] after update:
# [0.98825336 0.98212571]
# Gradient:
# [[-0.98825336 -0.98212571]
#  [ 0.98825336  0.98212571]]
# X=[1 2], theta=
# [[ 0.41328103  0.39736059]
#  [-0.38585312 -0.37095009]]
# exp_term:
# [0.69877588 0.7085465 ]
# sum_exp: 1.4073223816919902
# log_sum: 0.3416888788887947
# X=[1 2], class=0
# theta_c:
# [0.41328103 0.39736059]
# loss_contrib: 0.8663133339323092
# X=[3 4], theta=
# [[ 0.41328103  0.39736059]
#  [-0.38585312 -0.37095009]]
# exp_term:
# [0.73817865 0.74697872]
# sum_exp: 1.4851573708681327
# log_sum: 0.39552074028842676
# X=[3 4], class=1
# theta_c:
# [-0.38585312 -0.37095009]
# loss_contrib: -3.0368804677809096
# Total loss: -2.1705671338486003
# Iteration 3
# Loss: -2.1706
# Gradient:
# [[-0.98825336 -0.98212571]
#  [ 0.98825336  0.98212571]]
# Updated theta:
# [[ 0.41328103  0.39736059]
#  [-0.38585312 -0.37095009]]
# X=[1 2]
# exp_theta:
# [0.69877588 0.7085465 ]
# sum_exp_theta: 1.4073223816919902
# prob:
# [0.49652865 0.50347135]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50347135 1.00694271]
# grad[0] after update:
# [0.50347135 1.00694271]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50347135 -1.00694271]
# grad[1] after update:
# [-0.50347135 -1.00694271]
# X=[3 4]
# exp_theta:
# [0.73817865 0.74697872]
# sum_exp_theta: 1.4851573708681327
# prob:
# [0.49703732 0.50296268]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.49111197 -1.9881493 ]
# grad[0] after update:
# [-0.98764062 -0.98120659]
# Class 1
# indicator: 1
# grad_contrib:
# [1.49111197 1.9881493 ]
# grad[1] after update:
# [0.98764062 0.98120659]
# Gradient:
# [[-0.98764062 -0.98120659]
#  [ 0.98764062  0.98120659]]
# X=[1 2], theta=
# [[ 0.51204509  0.49548125]
#  [-0.48461719 -0.46907075]]
# exp_term:
# [0.6330605 0.6423254]
# sum_exp: 1.275385904992308
# log_sum: 0.24324880339709154
# X=[1 2], class=0
# theta_c:
# [0.51204509 0.49548125]
# loss_contrib: 1.2597587901379903
# X=[3 4], theta=
# [[ 0.51204509  0.49548125]
#  [-0.48461719 -0.46907075]]
# exp_term:
# [0.66875769 0.67716573]
# sum_exp: 1.3459234232442852
# log_sum: 0.29708033751220664
# X=[3 4], class=1
# theta_c:
# [-0.48461719 -0.46907075]
# loss_contrib: -3.627214888573893
# Total loss: -2.3674560984359028
# Iteration 4
# Loss: -2.3675
# Gradient:
# [[-0.98764062 -0.98120659]
#  [ 0.98764062  0.98120659]]
# Updated theta:
# [[ 0.51204509  0.49548125]
#  [-0.48461719 -0.46907075]]
# X=[1 2]
# exp_theta:
# [0.6330605 0.6423254]
# sum_exp_theta: 1.275385904992308
# prob:
# [0.4963678 0.5036322]
# Class 0
# indicator: 1
# grad_contrib:
# [0.5036322  1.00726439]
# grad[0] after update:
# [0.5036322  1.00726439]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.5036322  -1.00726439]
# grad[1] after update:
# [-0.5036322  -1.00726439]
# X=[3 4]
# exp_theta:
# [0.66875769 0.67716573]
# sum_exp_theta: 1.3459234232442852
# prob:
# [0.49687648 0.50312352]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.49062944 -1.98750592]
# grad[0] after update:
# [-0.98699724 -0.98024153]
# Class 1
# indicator: 1
# grad_contrib:
# [1.49062944 1.98750592]
# grad[1] after update:
# [0.98699724 0.98024153]
# Gradient:
# [[-0.98699724 -0.98024153]
#  [ 0.98699724  0.98024153]]
# X=[1 2], theta=
# [[ 0.61074481  0.5935054 ]
#  [-0.58331691 -0.5670949 ]]
# exp_term:
# [0.57356213 0.58234956]
# sum_exp: 1.1559116911479057
# log_sum: 0.1448893755916221
# X=[1 2], class=0
# theta_c:
# [0.61074481 0.5935054 ]
# loss_contrib: 1.652866248130015
# X=[3 4], theta=
# [[ 0.61074481  0.5935054 ]
#  [-0.58331691 -0.5670949 ]]
# exp_term:
# [0.60590431 0.61393674]
# sum_exp: 1.219841053279417
# log_sum: 0.19872056606024283
# X=[3 4], class=1
# theta_c:
# [-0.58331691 -0.5670949 ]
# loss_contrib: -4.217050901950472
# Total loss: -2.5641846538204573
# Iteration 5
# Loss: -2.5642
# Gradient:
# [[-0.98699724 -0.98024153]
#  [ 0.98699724  0.98024153]]
# Updated theta:
# [[ 0.61074481  0.5935054 ]
#  [-0.58331691 -0.5670949 ]]
# X=[1 2]
# exp_theta:
# [0.57356213 0.58234956]
# sum_exp_theta: 1.1559116911479057
# prob:
# [0.49619892 0.50380108]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50380108 1.00760216]
# grad[0] after update:
# [0.50380108 1.00760216]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50380108 -1.00760216]
# grad[1] after update:
# [-0.50380108 -1.00760216]
# X=[3 4]
# exp_theta:
# [0.60590431 0.61393674]
# sum_exp_theta: 1.219841053279417
# prob:
# [0.49670759 0.50329241]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.49012278 -1.98683038]
# grad[0] after update:
# [-0.9863217  -0.97922822]
# Class 1
# indicator: 1
# grad_contrib:
# [1.49012278 1.98683038]
# grad[1] after update:
# [0.9863217  0.97922822]
# Gradient:
# [[-0.9863217  -0.97922822]
#  [ 0.9863217   0.97922822]]
# X=[1 2], theta=
# [[ 0.70937698  0.69142823]
#  [-0.68194908 -0.66501772]]
# exp_term:
# [0.51969084 0.52802734]
# sum_exp: 1.0477181812653447
# log_sum: 0.046614638729452
# X=[1 2], class=0
# theta_c:
# [0.70937698 0.69142823]
# loss_contrib: 2.0456187988588876
# X=[3 4], theta=
# [[ 0.70937698  0.69142823]
#  [-0.68194908 -0.66501772]]
# exp_term:
# [0.54899531 0.55666803]
# sum_exp: 1.1056633464376324
# log_sum: 0.10044546837185592
# X=[3 4], class=1
# theta_c:
# [-0.68194908 -0.66501772]
# loss_contrib: -4.806363602311468
# Total loss: -2.7607448034525808
# Iteration 6
# Loss: -2.7607
# Gradient:
# [[-0.9863217  -0.97922822]
#  [ 0.9863217   0.97922822]]
# Updated theta:
# [[ 0.70937698  0.69142823]
#  [-0.68194908 -0.66501772]]
# X=[1 2]
# exp_theta:
# [0.51969084 0.52802734]
# sum_exp_theta: 1.0477181812653447
# prob:
# [0.49602159 0.50397841]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50397841 1.00795681]
# grad[0] after update:
# [0.50397841 1.00795681]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50397841 -1.00795681]
# grad[1] after update:
# [-0.50397841 -1.00795681]
# X=[3 4]
# exp_theta:
# [0.54899531 0.55666803]
# sum_exp_theta: 1.1056633464376324
# prob:
# [0.49653027 0.50346973]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.4895908  -1.98612106]
# grad[0] after update:
# [-0.98561239 -0.97816425]
# Class 1
# indicator: 1
# grad_contrib:
# [1.4895908  1.98612106]
# grad[1] after update:
# [0.98561239 0.97816425]
# Gradient:
# [[-0.98561239 -0.97816425]
#  [ 0.98561239  0.97816425]]
# X=[1 2], theta=
# [[ 0.80793822  0.78924465]
#  [-0.78051032 -0.76283415]]
# exp_term:
# [0.47091276 0.4788233 ]
# sum_exp: 0.9497360636879162
# log_sum: -0.051571160685745285
# X=[1 2], class=0
# theta_c:
# [0.80793822 0.78924465]
# loss_contrib: 2.437998687013688
# X=[3 4], theta=
# [[ 0.80793822  0.78924465]
#  [-0.78051032 -0.76283415]]
# exp_term:
# [0.49746672 0.50479512]
# sum_exp: 1.0022618442111397
# log_sum: 0.00225929009214312
# X=[3 4], class=1
# theta_c:
# [-0.78051032 -0.76283415]
# loss_contrib: -5.395126840479579
# Total loss: -2.9571281534658906
# Iteration 7
# Loss: -2.9571
# Gradient:
# [[-0.98561239 -0.97816425]
#  [ 0.98561239  0.97816425]]
# Updated theta:
# [[ 0.80793822  0.78924465]
#  [-0.78051032 -0.76283415]]
# X=[1 2]
# exp_theta:
# [0.47091276 0.4788233 ]
# sum_exp_theta: 0.9497360636879162
# prob:
# [0.4958354 0.5041646]
# Class 0
# indicator: 1
# grad_contrib:
# [0.5041646  1.00832919]
# grad[0] after update:
# [0.5041646  1.00832919]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.5041646  -1.00832919]
# grad[1] after update:
# [-0.5041646  -1.00832919]
# X=[3 4]
# exp_theta:
# [0.49746672 0.50479512]
# sum_exp_theta: 1.0022618442111397
# prob:
# [0.49634407 0.50365593]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.48903221 -1.98537628]
# grad[0] after update:
# [-0.98486762 -0.97704709]
# Class 1
# indicator: 1
# grad_contrib:
# [1.48903221 1.98537628]
# grad[1] after update:
# [0.98486762 0.97704709]
# Gradient:
# [[-0.98486762 -0.97704709]
#  [ 0.98486762  0.97704709]]
# X=[1 2], theta=
# [[ 0.90642499  0.88694936]
#  [-0.87899708 -0.86053886]]
# exp_term:
# [0.42674477 0.43425283]
# sum_exp: 0.8609975994658393
# log_sum: -0.1496635626351346
# X=[1 2], class=0
# theta_c:
# [0.90642499 0.88694936]
# loss_contrib: 2.829987268646262
# X=[3 4], theta=
# [[ 0.90642499  0.88694936]
#  [-0.87899708 -0.86053886]]
# exp_term:
# [0.45080817 0.45780711]
# sum_exp: 0.9086152791418255
# log_sum: -0.09583350966150189
# X=[3 4], class=1
# theta_c:
# [-0.87899708 -0.86053886]
# loss_contrib: -5.983313161724506
# Total loss: -3.1533258930782435
# Iteration 8
# Loss: -3.1533
# Gradient:
# [[-0.98486762 -0.97704709]
#  [ 0.98486762  0.97704709]]
# Updated theta:
# [[ 0.90642499  0.88694936]
#  [-0.87899708 -0.86053886]]
# X=[1 2]
# exp_theta:
# [0.42674477 0.43425283]
# sum_exp_theta: 0.8609975994658393
# prob:
# [0.4956399 0.5043601]
# Class 0
# indicator: 1
# grad_contrib:
# [0.5043601  1.00872019]
# grad[0] after update:
# [0.5043601  1.00872019]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.5043601  -1.00872019]
# grad[1] after update:
# [-0.5043601  -1.00872019]
# X=[3 4]
# exp_theta:
# [0.45080817 0.45780711]
# sum_exp_theta: 0.9086152791418255
# prob:
# [0.49614857 0.50385143]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.48844571 -1.98459428]
# grad[0] after update:
# [-0.98408561 -0.97587408]
# Class 1
# indicator: 1
# grad_contrib:
# [1.48844571 1.98459428]
# grad[1] after update:
# [0.98408561 0.97587408]
# Gradient:
# [[-0.98408561 -0.97587408]
#  [ 0.98408561  0.97587408]]
# X=[1 2], theta=
# [[ 1.00483355  0.98453677]
#  [-0.97740564 -0.95812626]]
# exp_term:
# [0.38674963 0.39387733]
# sum_exp: 0.7806269635160803
# log_sum: -0.24765788279262527
# X=[1 2], class=0
# theta_c:
# [1.00483355 0.98453677]
# loss_contrib: 3.221564966673379
# X=[3 4], theta=
# [[ 1.00483355  0.98453677]
#  [-0.97740564 -0.95812626]]
# exp_term:
# [0.40855778 0.4152416 ]
# sum_exp: 0.8237993817142204
# log_sum: -0.19382824750942546
# X=[3 4], class=1
# theta_c:
# [-0.97740564 -0.95812626]
# loss_contrib: -6.5708937407149275
# Total loss: -3.3493287740415485
# Iteration 9
# Loss: -3.3493
# Gradient:
# [[-0.98408561 -0.97587408]
#  [ 0.98408561  0.97587408]]
# Updated theta:
# [[ 1.00483355  0.98453677]
#  [-0.97740564 -0.95812626]]
# X=[1 2]
# exp_theta:
# [0.38674963 0.39387733]
# sum_exp_theta: 0.7806269635160803
# prob:
# [0.49543463 0.50456537]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50456537 1.00913074]
# grad[0] after update:
# [0.50456537 1.00913074]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50456537 -1.00913074]
# grad[1] after update:
# [-0.50456537 -1.00913074]
# X=[3 4]
# exp_theta:
# [0.40855778 0.4152416 ]
# sum_exp_theta: 0.8237993817142204
# prob:
# [0.49594329 0.50405671]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.48782988 -1.98377317]
# grad[0] after update:
# [-0.98326451 -0.97464244]
# Class 1
# indicator: 1
# grad_contrib:
# [1.48782988 1.98377317]
# grad[1] after update:
# [0.98326451 0.97464244]
# Gradient:
# [[-0.98326451 -0.97464244]
#  [ 0.98326451  0.97464244]]
# X=[1 2], theta=
# [[ 1.10316     1.08200101]
#  [-1.07573209 -1.05559051]]
# exp_term:
# [0.35053168 0.35729982]
# sum_exp: 0.7078315048003074
# log_sum: -0.34554920118214016
# X=[1 2], class=0
# theta_c:
# [1.10316    1.08200101]
# loss_contrib: 3.612711224150921
# X=[3 4], theta=
# [[ 1.10316     1.08200101]
#  [-1.07573209 -1.05559051]]
# exp_term:
# [0.37029756 0.3766801 ]
# sum_exp: 0.7469776571010774
# log_sum: -0.29172000446922497
# X=[3 4], class=1
# theta_c:
# [-1.07573209 -1.05559051]
# loss_contrib: -7.157838313246984
# Total loss: -3.545127089096063
# Iteration 10
# Loss: -3.5451
# Gradient:
# [[-0.98326451 -0.97464244]
#  [ 0.98326451  0.97464244]]
# Updated theta:
# [[ 1.10316     1.08200101]
#  [-1.07573209 -1.05559051]]
# X=[1 2]
# exp_theta:
# [0.35053168 0.35729982]
# sum_exp_theta: 0.7078315048003074
# prob:
# [0.4952191 0.5047809]
# Class 0
# indicator: 1
# grad_contrib:
# [0.5047809 1.0095618]
# grad[0] after update:
# [0.5047809 1.0095618]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.5047809 -1.0095618]
# grad[1] after update:
# [-0.5047809 -1.0095618]
# X=[3 4]
# exp_theta:
# [0.37029756 0.3766801 ]
# sum_exp_theta: 0.7469776571010774
# prob:
# [0.49572776 0.50427224]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.48718327 -1.98291103]
# grad[0] after update:
# [-0.98240237 -0.97334923]
# Class 1
# indicator: 1
# grad_contrib:
# [1.48718327 1.98291103]
# grad[1] after update:
# [0.98240237 0.97334923]
# Gradient:
# [[-0.98240237 -0.97334923]
#  [ 0.98240237  0.97334923]]
# X=[1 2], theta=
# [[ 1.20140023  1.17933594]
#  [-1.17397233 -1.15292543]]
# exp_term:
# [0.31773282 0.32416101]
# sum_exp: 0.6418938380519055
# log_sum: -0.44333235025572826
# X=[1 2], class=0
# theta_c:
# [1.20140023 1.17933594]
# loss_contrib: 4.0034044552089725
# X=[3 4], theta=
# [[ 1.20140023  1.17933594]
#  [-1.17397233 -1.15292543]]
# exp_term:
# [0.33564923 0.34174381]
# sum_exp: 0.6773930394542363
# log_sum: -0.38950361403620565
# X=[3 4], class=1
# theta_c:
# [-1.17397233 -1.15292543]
# loss_contrib: -7.744115104591944
# Total loss: -3.7407106493829714
# Iteration 11
# Loss: -3.7407
# Gradient:
# [[-0.98240237 -0.97334923]
#  [ 0.98240237  0.97334923]]
# Updated theta:
# [[ 1.20140023  1.17933594]
#  [-1.17397233 -1.15292543]]
# X=[1 2]
# exp_theta:
# [0.31773282 0.32416101]
# sum_exp_theta: 0.6418938380519055
# prob:
# [0.49499279 0.50500721]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50500721 1.01001442]
# grad[0] after update:
# [0.50500721 1.01001442]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50500721 -1.01001442]
# grad[1] after update:
# [-0.50500721 -1.01001442]
# X=[3 4]
# exp_theta:
# [0.33564923 0.34174381]
# sum_exp_theta: 0.6773930394542363
# prob:
# [0.49550145 0.50449855]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.48650434 -1.98200578]
# grad[0] after update:
# [-0.98149713 -0.97199137]
# Class 1
# indicator: 1
# grad_contrib:
# [1.48650434 1.98200578]
# grad[1] after update:
# [0.98149713 0.97199137]
# Gradient:
# [[-0.98149713 -0.97199137]
#  [ 0.98149713  0.97199137]]
# X=[1 2], theta=
# [[ 1.29954995  1.27653507]
#  [-1.27212204 -1.25012457]]
# exp_term:
# [0.28802899 0.2941357 ]
# sum_exp: 0.5821646879093192
# log_sum: -0.5410019023624961
# X=[1 2], class=0
# theta_c:
# [1.29954995 1.27653507]
# loss_contrib: 4.393621993531244
# X=[3 4], theta=
# [[ 1.29954995  1.27653507]
#  [-1.27212204 -1.25012457]]
# exp_term:
# [0.30427045 0.31008989]
# sum_exp: 0.6143603402203329
# log_sum: -0.48717364965477805
# X=[3 4], class=1
# theta_c:
# [-1.27212204 -1.25012457]
# loss_contrib: -8.329690754298326
# Total loss: -3.936068760767082
# Iteration 12
# Loss: -3.9361
# Gradient:
# [[-0.98149713 -0.97199137]
#  [ 0.98149713  0.97199137]]
# Updated theta:
# [[ 1.29954995  1.27653507]
#  [-1.27212204 -1.25012457]]
# X=[1 2]
# exp_theta:
# [0.28802899 0.2941357 ]
# sum_exp_theta: 0.5821646879093192
# prob:
# [0.49475517 0.50524483]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50524483 1.01048965]
# grad[0] after update:
# [0.50524483 1.01048965]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50524483 -1.01048965]
# grad[1] after update:
# [-0.50524483 -1.01048965]
# X=[3 4]
# exp_theta:
# [0.30427045 0.31008989]
# sum_exp_theta: 0.6143603402203329
# prob:
# [0.49526382 0.50473618]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.48579147 -1.98105529]
# grad[0] after update:
# [-0.98054664 -0.97056563]
# Class 1
# indicator: 1
# grad_contrib:
# [1.48579147 1.98105529]
# grad[1] after update:
# [0.98054664 0.97056563]
# Gradient:
# [[-0.98054664 -0.97056563]
#  [ 0.98054664  0.97056563]]
# X=[1 2], theta=
# [[ 1.39760461  1.37359164]
#  [-1.37017671 -1.34718113]]
# exp_term:
# [0.26112689 0.26692952]
# sum_exp: 0.5280564138466777
# log_sum: -0.6385521565767461
# X=[1 2], class=0
# theta_c:
# [1.39760461 1.37359164]
# loss_contrib: 4.7833400382565765
# X=[3 4], theta=
# [[ 1.39760461  1.37359164]
#  [-1.37017671 -1.34718113]]
# exp_term:
# [0.27585139 0.28140802]
# sum_exp: 0.5572594149113319
# log_sum: -0.5847244115491801
# X=[3 4], class=1
# theta_c:
# [-1.37017671 -1.34718113]
# loss_contrib: -8.914530237276153
# Total loss: -4.131190199019577
# Iteration 13
# Loss: -4.1312
# Gradient:
# [[-0.98054664 -0.97056563]
#  [ 0.98054664  0.97056563]]
# Updated theta:
# [[ 1.39760461  1.37359164]
#  [-1.37017671 -1.34718113]]
# X=[1 2]
# exp_theta:
# [0.26112689 0.26692952]
# sum_exp_theta: 0.5280564138466777
# prob:
# [0.49450568 0.50549432]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50549432 1.01098865]
# grad[0] after update:
# [0.50549432 1.01098865]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50549432 -1.01098865]
# grad[1] after update:
# [-0.50549432 -1.01098865]
# X=[3 4]
# exp_theta:
# [0.27585139 0.28140802]
# sum_exp_theta: 0.5572594149113319
# prob:
# [0.49501432 0.50498568]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.48504296 -1.98005728]
# grad[0] after update:
# [-0.97954864 -0.96906863]
# Class 1
# indicator: 1
# grad_contrib:
# [1.48504296 1.98005728]
# grad[1] after update:
# [0.97954864 0.96906863]
# Gradient:
# [[-0.97954864 -0.96906863]
#  [ 0.97954864  0.96906863]]
# X=[1 2], theta=
# [[ 1.49555948  1.4704985 ]
#  [-1.46813157 -1.44408799]]
# exp_term:
# [0.2367611  0.24227605]
# sum_exp: 0.4790371511091248
# log_sum: -0.7359771248520478
# X=[1 2], class=0
# theta_c:
# [1.49555948 1.4704985 ]
# loss_contrib: 5.1725335971743345
# X=[3 4], theta=
# [[ 1.49555948  1.4704985 ]
#  [-1.46813157 -1.44408799]]
# exp_term:
# [0.25011165 0.25541733]
# sum_exp: 0.5055289799533719
# log_sum: -0.6821499128802586
# X=[3 4], class=1
# theta_c:
# [-1.46813157 -1.44408799]
# loss_contrib: -9.498596780983048
# Total loss: -4.326063183808714
# Iteration 14
# Loss: -4.3261
# Gradient:
# [[-0.97954864 -0.96906863]
#  [ 0.97954864  0.96906863]]
# Updated theta:
# [[ 1.49555948  1.4704985 ]
#  [-1.46813157 -1.44408799]]
# X=[1 2]
# exp_theta:
# [0.2367611  0.24227605]
# sum_exp_theta: 0.4790371511091248
# prob:
# [0.49424371 0.50575629]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50575629 1.01151258]
# grad[0] after update:
# [0.50575629 1.01151258]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50575629 -1.01151258]
# grad[1] after update:
# [-0.50575629 -1.01151258]
# X=[3 4]
# exp_theta:
# [0.25011165 0.25541733]
# sum_exp_theta: 0.5055289799533719
# prob:
# [0.49475235 0.50524765]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.48425704 -1.97900939]
# grad[0] after update:
# [-0.97850075 -0.96749681]
# Class 1
# indicator: 1
# grad_contrib:
# [1.48425704 1.97900939]
# grad[1] after update:
# [0.97850075 0.96749681]
# Gradient:
# [[-0.97850075 -0.96749681]
#  [ 0.97850075  0.96749681]]
# X=[1 2], theta=
# [[ 1.59340955  1.56724818]
#  [-1.56598165 -1.54083768]]
# exp_term:
# [0.21469138 0.21993413]
# sum_exp: 0.43462550902784247
# log_sum: -0.8332705174662038
# X=[1 2], class=0
# theta_c:
# [1.59340955 1.56724818]
# loss_contrib: 5.561176427079322
# X=[3 4], theta=
# [[ 1.59340955  1.56724818]
#  [-1.56598165 -1.54083768]]
# exp_term:
# [0.22679745 0.23186356]
# sum_exp: 0.45866101774612855
# log_sum: -0.7794438651932754
# X=[3 4], class=1
# theta_c:
# [-1.56598165 -1.54083768]
# loss_contrib: -10.081851778523697
# Total loss: -4.520675351444376
# Iteration 15
# Loss: -4.5207
# Gradient:
# [[-0.97850075 -0.96749681]
#  [ 0.97850075  0.96749681]]
# Updated theta:
# [[ 1.59340955  1.56724818]
#  [-1.56598165 -1.54083768]]
# X=[1 2]
# exp_theta:
# [0.21469138 0.21993413]
# sum_exp_theta: 0.43462550902784247
# prob:
# [0.49396865 0.50603135]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50603135 1.0120627 ]
# grad[0] after update:
# [0.50603135 1.0120627 ]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50603135 -1.0120627 ]
# grad[1] after update:
# [-0.50603135 -1.0120627 ]
# X=[3 4]
# exp_theta:
# [0.22679745 0.23186356]
# sum_exp_theta: 0.45866101774612855
# prob:
# [0.49447728 0.50552272]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.48343184 -1.97790912]
# grad[0] after update:
# [-0.97740049 -0.96584642]
# Class 1
# indicator: 1
# grad_contrib:
# [1.48343184 1.97790912]
# grad[1] after update:
# [0.97740049 0.96584642]
# Gradient:
# [[-0.97740049 -0.96584642]
#  [ 0.97740049  0.96584642]]
# X=[1 2], theta=
# [[ 1.6911496   1.66383282]
#  [-1.6637217  -1.63742232]]
# exp_term:
# [0.19470031 0.19968547]
# sum_exp: 0.39438577367016614
# log_sum: -0.930425727720233
# X=[1 2], class=0
# theta_c:
# [1.6911496  1.66383282]
# loss_contrib: 5.949240971145364
# X=[3 4], theta=
# [[ 1.6911496   1.66383282]
#  [-1.6637217  -1.63742232]]
# exp_term:
# [0.20567912 0.21051659]
# sum_exp: 0.41619571395398436
# log_sum: -0.8765996631198754
# X=[3 4], class=1
# theta_c:
# [-1.6637217  -1.63742232]
# loss_contrib: -10.664254697465601
# Total loss: -4.715013726320238
# Iteration 16
# Loss: -4.7150
# Gradient:
# [[-0.97740049 -0.96584642]
#  [ 0.97740049  0.96584642]]
# Updated theta:
# [[ 1.6911496   1.66383282]
#  [-1.6637217  -1.63742232]]
# X=[1 2]
# exp_theta:
# [0.19470031 0.19968547]
# sum_exp_theta: 0.39438577367016614
# prob:
# [0.49367984 0.50632016]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50632016 1.01264032]
# grad[0] after update:
# [0.50632016 1.01264032]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50632016 -1.01264032]
# grad[1] after update:
# [-0.50632016 -1.01264032]
# X=[3 4]
# exp_theta:
# [0.20567912 0.21051659]
# sum_exp_theta: 0.41619571395398436
# prob:
# [0.49418847 0.50581153]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.4825654  -1.97675387]
# grad[0] after update:
# [-0.97624524 -0.96411355]
# Class 1
# indicator: 1
# grad_contrib:
# [1.4825654  1.97675387]
# grad[1] after update:
# [0.97624524 0.96411355]
# Gradient:
# [[-0.97624524 -0.96411355]
#  [ 0.97624524  0.96411355]]
# X=[1 2], theta=
# [[ 1.78877412  1.76024418]
#  [-1.76134622 -1.73383367]]
# exp_term:
# [0.17659111 0.18133245]
# sum_exp: 0.3579235668293639
# log_sum: -1.0274358158525452
# X=[1 2], class=0
# theta_c:
# [1.78877412 1.76024418]
# loss_contrib: 6.336698293170002
# X=[3 4], theta=
# [[ 1.78877412  1.76024418]
#  [-1.76134622 -1.73383367]]
# exp_term:
# [0.18654878 0.19116809]
# sum_exp: 0.3777168763787656
# log_sum: -0.973610368295386
# X=[3 4], class=1
# theta_c:
# [-1.76134622 -1.73383367]
# loss_contrib: -11.245762984165308
# Total loss: -4.909064690995306
# Iteration 17
# Loss: -4.9091
# Gradient:
# [[-0.97624524 -0.96411355]
#  [ 0.97624524  0.96411355]]
# Updated theta:
# [[ 1.78877412  1.76024418]
#  [-1.76134622 -1.73383367]]
# X=[1 2]
# exp_theta:
# [0.17659111 0.18133245]
# sum_exp_theta: 0.3579235668293639
# prob:
# [0.4933766 0.5066234]
# Class 0
# indicator: 1
# grad_contrib:
# [0.5066234 1.0132468]
# grad[0] after update:
# [0.5066234 1.0132468]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.5066234 -1.0132468]
# grad[1] after update:
# [-0.5066234 -1.0132468]
# X=[3 4]
# exp_theta:
# [0.18654878 0.19116809]
# sum_exp_theta: 0.3777168763787656
# prob:
# [0.49388522 0.50611478]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.48165565 -1.97554087]
# grad[0] after update:
# [-0.97503225 -0.96229407]
# Class 1
# indicator: 1
# grad_contrib:
# [1.48165565 1.97554087]
# grad[1] after update:
# [0.97503225 0.96229407]
# Gradient:
# [[-0.97503225 -0.96229407]
#  [ 0.97503225  0.96229407]]
# X=[1 2], theta=
# [[ 1.88627735  1.85647358]
#  [-1.85884945 -1.83006308]]
# exp_term:
# [0.1601857  0.16469622]
# sum_exp: 0.3248819179271554
# log_sum: -1.1242934921274443
# X=[1 2], class=0
# theta_c:
# [1.88627735 1.85647358]
# loss_contrib: 6.723518008535715
# X=[3 4], theta=
# [[ 1.88627735  1.85647358]
#  [-1.85884945 -1.83006308]]
# exp_term:
# [0.16921829 0.1736295 ]
# sum_exp: 0.34284778958500683
# log_sum: -1.070468692450593
# X=[3 4], class=1
# theta_c:
# [-1.85884945 -1.83006308]
# loss_contrib: -11.82633196339009
# Total loss: -5.1028139548543745
# Iteration 18
# Loss: -5.1028
# Gradient:
# [[-0.97503225 -0.96229407]
#  [ 0.97503225  0.96229407]]
# Updated theta:
# [[ 1.88627735  1.85647358]
#  [-1.85884945 -1.83006308]]
# X=[1 2]
# exp_theta:
# [0.1601857  0.16469622]
# sum_exp_theta: 0.3248819179271554
# prob:
# [0.4930582 0.5069418]
# Class 0
# indicator: 1
# grad_contrib:
# [0.5069418  1.01388359]
# grad[0] after update:
# [0.5069418  1.01388359]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.5069418  -1.01388359]
# grad[1] after update:
# [-0.5069418  -1.01388359]
# X=[3 4]
# exp_theta:
# [0.16921829 0.1736295 ]
# sum_exp_theta: 0.34284778958500683
# prob:
# [0.49356681 0.50643319]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.48070044 -1.97426725]
# grad[0] after update:
# [-0.97375864 -0.96038366]
# Class 1
# indicator: 1
# grad_contrib:
# [1.48070044 1.97426725]
# grad[1] after update:
# [0.97375864 0.96038366]
# Gradient:
# [[-0.97375864 -0.96038366]
#  [ 0.97375864  0.96038366]]
# X=[1 2], theta=
# [[ 1.98365321  1.95251195]
#  [-1.95622531 -1.92610145]]
# exp_term:
# [0.14532286 0.14961485]
# sum_exp: 0.2949377095356448
# log_sum: -1.2209910990549446
# X=[1 2], class=0
# theta_c:
# [1.98365321 1.95251195]
# loss_contrib: 7.1096682117258165
# X=[3 4], theta=
# [[ 1.98365321  1.95251195]
#  [-1.95622531 -1.92610145]]
# exp_term:
# [0.15351736 0.1577301 ]
# sum_exp: 0.3112474638109428
# log_sum: -1.1671669796349953
# X=[3 4], class=1
# theta_c:
# [-1.95622531 -1.92610145]
# loss_contrib: -12.405914733010723
# Total loss: -5.296246521284907
# Iteration 19
# Loss: -5.2962
# Gradient:
# [[-0.97375864 -0.96038366]
#  [ 0.97375864  0.96038366]]
# Updated theta:
# [[ 1.98365321  1.95251195]
#  [-1.95622531 -1.92610145]]
# X=[1 2]
# exp_theta:
# [0.14532286 0.14961485]
# sum_exp_theta: 0.2949377095356448
# prob:
# [0.4927239 0.5072761]
# Class 0
# indicator: 1
# grad_contrib:
# [0.5072761  1.01455221]
# grad[0] after update:
# [0.5072761  1.01455221]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.5072761  -1.01455221]
# grad[1] after update:
# [-0.5072761  -1.01455221]
# X=[3 4]
# exp_theta:
# [0.15351736 0.1577301 ]
# sum_exp_theta: 0.3112474638109428
# prob:
# [0.4932325 0.5067675]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.47969749 -1.97292999]
# grad[0] after update:
# [-0.97242139 -0.95837778]
# Class 1
# indicator: 1
# grad_contrib:
# [1.47969749 1.97292999]
# grad[1] after update:
# [0.97242139 0.95837778]
# Gradient:
# [[-0.97242139 -0.95837778]
#  [ 0.97242139  0.95837778]]
# X=[1 2], theta=
# [[ 2.08089535  2.04834973]
#  [-2.05346745 -2.02193922]]
# exp_term:
# [0.1318567  0.13594176]
# sum_exp: 0.2677984609654358
# log_sum: -1.3175205926966356
# X=[1 2], class=0
# theta_c:
# [2.08089535 2.04834973]
# loss_contrib: 7.495115400225632
# X=[3 4], theta=
# [[ 2.08089535  2.04834973]
#  [-2.05346745 -2.02193922]]
# exp_term:
# [0.13929187 0.14331537]
# sum_exp: 0.2826072406454142
# log_sum: -1.2636971875262692
# X=[3 4], class=1
# theta_c:
# [-2.05346745 -2.02193922]
# loss_contrib: -12.984462053531267
# Total loss: -5.489346653305635
# Iteration 20
# Loss: -5.4893
# Gradient:
# [[-0.97242139 -0.95837778]
#  [ 0.97242139  0.95837778]]
# Updated theta:
# [[ 2.08089535  2.04834973]
#  [-2.05346745 -2.02193922]]
# X=[1 2]
# exp_theta:
# [0.1318567  0.13594176]
# sum_exp_theta: 0.2677984609654358
# prob:
# [0.49237289 0.50762711]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50762711 1.01525423]
# grad[0] after update:
# [0.50762711 1.01525423]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50762711 -1.01525423]
# grad[1] after update:
# [-0.50762711 -1.01525423]
# X=[3 4]
# exp_theta:
# [0.13929187 0.14331537]
# sum_exp_theta: 0.2826072406454142
# prob:
# [0.49288147 0.50711853]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.47864442 -1.9715259 ]
# grad[0] after update:
# [-0.97101731 -0.95627167]
# Class 1
# indicator: 1
# grad_contrib:
# [1.47864442 1.9715259 ]
# grad[1] after update:
# [0.97101731 0.95627167]
# Gradient:
# [[-0.97101731 -0.95627167]
#  [ 0.97101731  0.95627167]]
# X=[1 2], theta=
# [[ 2.17799708  2.14397689]
#  [-2.15056918 -2.11756639]]
# exp_term:
# [0.11965517 0.12354425]
# sum_exp: 0.24319941775075243
# log_sum: -1.4138735230099628
# X=[1 2], class=0
# theta_c:
# [2.17799708 2.14397689]
# loss_contrib: 7.8798243946316795
# X=[3 4], theta=
# [[ 2.17799708  2.14397689]
#  [-2.15056918 -2.11756639]]
# exp_term:
# [0.12640232 0.1302454 ]
# sum_exp: 0.2566477215221044
# log_sum: -1.3600508677783167
# X=[3 4], class=1
# theta_c:
# [-2.15056918 -2.11756639]
# loss_contrib: -13.561922232211842
# Total loss: -5.682097837580162
# Iteration 21
# Loss: -5.6821
# Gradient:
# [[-0.97101731 -0.95627167]
#  [ 0.97101731  0.95627167]]
# Updated theta:
# [[ 2.17799708  2.14397689]
#  [-2.15056918 -2.11756639]]
# X=[1 2]
# exp_theta:
# [0.11965517 0.12354425]
# sum_exp_theta: 0.24319941775075243
# prob:
# [0.49200433 0.50799567]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50799567 1.01599133]
# grad[0] after update:
# [0.50799567 1.01599133]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50799567 -1.01599133]
# grad[1] after update:
# [-0.50799567 -1.01599133]
# X=[3 4]
# exp_theta:
# [0.12640232 0.1302454 ]
# sum_exp_theta: 0.2566477215221044
# prob:
# [0.49251291 0.50748709]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.47753874 -1.97005165]
# grad[0] after update:
# [-0.96954307 -0.95406032]
# Class 1
# indicator: 1
# grad_contrib:
# [1.47753874 1.97005165]
# grad[1] after update:
# [0.96954307 0.95406032]
# Gradient:
# [[-0.96954307 -0.95406032]
#  [ 0.96954307  0.95406032]]
# X=[1 2], theta=
# [[ 2.27495139  2.23938293]
#  [-2.24752349 -2.21297242]]
# exp_term:
# [0.10859873 0.11230219]
# sum_exp: 0.22090091792429906
# log_sum: -1.5100410131808193
# X=[1 2], class=0
# theta_c:
# [2.27495139 2.23938293]
# loss_contrib: 8.263758254783522
# X=[3 4], theta=
# [[ 2.27495139  2.23938293]
#  [-2.24752349 -2.21297242]]
# exp_term:
# [0.11472242 0.11839356]
# sum_exp: 0.23311598831380112
# log_sum: -1.4562191453578108
# X=[3 4], class=1
# theta_c:
# [-2.24752349 -2.21297242]
# loss_contrib: -14.1382410015302
# Total loss: -5.874482746746679
# Iteration 22
# Loss: -5.8745
# Gradient:
# [[-0.96954307 -0.95406032]
#  [ 0.96954307  0.95406032]]
# Updated theta:
# [[ 2.27495139  2.23938293]
#  [-2.24752349 -2.21297242]]
# X=[1 2]
# exp_theta:
# [0.10859873 0.11230219]
# sum_exp_theta: 0.22090091792429906
# prob:
# [0.49161737 0.50838263]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50838263 1.01676526]
# grad[0] after update:
# [0.50838263 1.01676526]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50838263 -1.01676526]
# grad[1] after update:
# [-0.50838263 -1.01676526]
# X=[3 4]
# exp_theta:
# [0.11472242 0.11839356]
# sum_exp_theta: 0.23311598831380112
# prob:
# [0.49212593 0.50787407]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.4763778  -1.96850374]
# grad[0] after update:
# [-0.96799517 -0.95173848]
# Class 1
# indicator: 1
# grad_contrib:
# [1.4763778  1.96850374]
# grad[1] after update:
# [0.96799517 0.95173848]
# Gradient:
# [[-0.96799517 -0.95173848]
#  [ 0.96799517  0.95173848]]
# X=[1 2], theta=
# [[ 2.37175091  2.33455677]
#  [-2.344323   -2.30814627]]
# exp_term:
# [0.09857919 0.10210682]
# sum_exp: 0.2006860087450293
# log_sum: -1.6060137378917256
# X=[1 2], class=0
# theta_c:
# [2.37175091 2.33455677]
# loss_contrib: 8.646878191724563
# X=[3 4], theta=
# [[ 2.37175091  2.33455677]
#  [-2.344323   -2.30814627]]
# exp_term:
# [0.1041379  0.10764519]
# sum_exp: 0.21178308823306335
# log_sum: -1.5521926968165136
# X=[3 4], class=1
# theta_c:
# [-2.344323   -2.30814627]
# loss_contrib: -14.713361391717532
# Total loss: -6.06648319999297
# Iteration 23
# Loss: -6.0665
# Gradient:
# [[-0.96799517 -0.95173848]
#  [ 0.96799517  0.95173848]]
# Updated theta:
# [[ 2.37175091  2.33455677]
#  [-2.344323   -2.30814627]]
# X=[1 2]
# exp_theta:
# [0.09857919 0.10210682]
# sum_exp_theta: 0.2006860087450293
# prob:
# [0.49121107 0.50878893]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50878893 1.01757786]
# grad[0] after update:
# [0.50878893 1.01757786]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50878893 -1.01757786]
# grad[1] after update:
# [-0.50878893 -1.01757786]
# X=[3 4]
# exp_theta:
# [0.1041379  0.10764519]
# sum_exp_theta: 0.21178308823306335
# prob:
# [0.49171962 0.50828038]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.47515887 -1.96687849]
# grad[0] after update:
# [-0.96636994 -0.94930063]
# Class 1
# indicator: 1
# grad_contrib:
# [1.47515887 1.96687849]
# grad[1] after update:
# [0.96636994 0.94930063]
# Gradient:
# [[-0.96636994 -0.94930063]
#  [ 0.96636994  0.94930063]]
# X=[1 2], theta=
# [[ 2.4683879   2.42948684]
#  [-2.44096    -2.40307633]]
# exp_term:
# [0.08949862 0.09285967]
# sum_exp: 0.18235829004869883
# log_sum: -1.701781900470183
# X=[1 2], class=0
# theta_c:
# [2.4683879  2.42948684]
# loss_contrib: 9.029143475289409
# X=[3 4], theta=
# [[ 2.4683879   2.42948684]
#  [-2.44096    -2.40307633]]
# exp_term:
# [0.09454529 0.09789647]
# sum_exp: 0.19244175789103002
# log_sum: -1.6479617274439566
# X=[3 4], class=1
# theta_c:
# [-2.44096    -2.40307633]
# loss_contrib: -15.287223597093302
# Total loss: -6.258080121803893
# Iteration 24
# Loss: -6.2581
# Gradient:
# [[-0.96636994 -0.94930063]
#  [ 0.96636994  0.94930063]]
# Updated theta:
# [[ 2.4683879   2.42948684]
#  [-2.44096    -2.40307633]]
# X=[1 2]
# exp_theta:
# [0.08949862 0.09285967]
# sum_exp_theta: 0.18235829004869883
# prob:
# [0.49078448 0.50921552]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50921552 1.01843105]
# grad[0] after update:
# [0.50921552 1.01843105]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50921552 -1.01843105]
# grad[1] after update:
# [-0.50921552 -1.01843105]
# X=[3 4]
# exp_theta:
# [0.09454529 0.09789647]
# sum_exp_theta: 0.19244175789103002
# prob:
# [0.49129301 0.50870699]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.47387904 -1.96517205]
# grad[0] after update:
# [-0.96466352 -0.94674101]
# Class 1
# indicator: 1
# grad_contrib:
# [1.47387904 1.96517205]
# grad[1] after update:
# [0.96466352 0.94674101]
# Gradient:
# [[-0.96466352 -0.94674101]
#  [ 0.96466352  0.94674101]]
# X=[1 2], theta=
# [[ 2.56485425  2.52416094]
#  [-2.53742635 -2.49775043]]
# exp_term:
# [0.08126837 0.0844716 ]
# sum_exp: 0.16573996265916713
# log_sum: -1.7973352088589183
# X=[1 2], class=0
# theta_c:
# [2.56485425 2.52416094]
# loss_contrib: 9.410511337106612
# X=[3 4], theta=
# [[ 2.56485425  2.52416094]
#  [-2.53742635 -2.49775043]]
# exp_term:
# [0.08585095 0.08905341]
# sum_exp: 0.17490436375965274
# log_sum: -1.743515947242225
# X=[3 4], class=1
# theta_c:
# [-2.53742635 -2.49775043]
# loss_contrib: -15.859764835913234
# Total loss: -6.4492534988066215
# Iteration 25
# Loss: -6.4493
# Gradient:
# [[-0.96466352 -0.94674101]
#  [ 0.96466352  0.94674101]]
# Updated theta:
# [[ 2.56485425  2.52416094]
#  [-2.53742635 -2.49775043]]
# X=[1 2]
# exp_theta:
# [0.08126837 0.0844716 ]
# sum_exp_theta: 0.16573996265916713
# prob:
# [0.49033657 0.50966343]
# Class 0
# indicator: 1
# grad_contrib:
# [0.50966343 1.01932685]
# grad[0] after update:
# [0.50966343 1.01932685]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.50966343 -1.01932685]
# grad[1] after update:
# [-0.50966343 -1.01932685]
# X=[3 4]
# exp_theta:
# [0.08585095 0.08905341]
# sum_exp_theta: 0.17490436375965274
# prob:
# [0.49084509 0.50915491]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.47253528 -1.96338037]
# grad[0] after update:
# [-0.96287186 -0.94405352]
# Class 1
# indicator: 1
# grad_contrib:
# [1.47253528 1.96338037]
# grad[1] after update:
# [0.96287186 0.94405352]
# Gradient:
# [[-0.96287186 -0.94405352]
#  [ 0.96287186  0.94405352]]
# X=[1 2], theta=
# [[ 2.66114144  2.61856629]
#  [-2.63371354 -2.59215579]]
# exp_term:
# [0.07380819 0.07686188]
# sum_exp: 0.15067006235059677
# log_sum: -1.8926628503467864
# X=[1 2], class=0
# theta_c:
# [2.66114144 2.61856629]
# loss_contrib: 9.790936868796445
# X=[3 4], theta=
# [[ 2.66114144  2.61856629]
#  [-2.63371354 -2.59215579]]
# exp_term:
# [0.0779701  0.08103094]
# sum_exp: 0.1590010384483394
# log_sum: -1.8388445456616018
# X=[3 4], class=1
# theta_c:
# [-2.63371354 -2.59215579]
# loss_contrib: -16.430919203433852
# Total loss: -6.639982334637407
# Iteration 26
# Loss: -6.6400
# Gradient:
# [[-0.96287186 -0.94405352]
#  [ 0.96287186  0.94405352]]
# Updated theta:
# [[ 2.66114144  2.61856629]
#  [-2.63371354 -2.59215579]]
# X=[1 2]
# exp_theta:
# [0.07380819 0.07686188]
# sum_exp_theta: 0.15067006235059677
# prob:
# [0.4898663 0.5101337]
# Class 0
# indicator: 1
# grad_contrib:
# [0.5101337 1.0202674]
# grad[0] after update:
# [0.5101337 1.0202674]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.5101337 -1.0202674]
# grad[1] after update:
# [-0.5101337 -1.0202674]
# X=[3 4]
# exp_theta:
# [0.0779701  0.08103094]
# sum_exp_theta: 0.1590010384483394
# prob:
# [0.4903748 0.5096252]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.4711244  -1.96149921]
# grad[0] after update:
# [-0.9609907  -0.94123181]
# Class 1
# indicator: 1
# grad_contrib:
# [1.4711244  1.96149921]
# grad[1] after update:
# [0.9609907  0.94123181]
# Gradient:
# [[-0.9609907  -0.94123181]
#  [ 0.9609907   0.94123181]]
# X=[1 2], theta=
# [[ 2.75724051  2.71268947]
#  [-2.72981261 -2.68627897]]
# exp_term:
# [0.06704544 0.06995742]
# sum_exp: 0.13700286170753487
# log_sum: -1.9877534649960042
# X=[1 2], class=0
# theta_c:
# [2.75724051 2.71268947]
# loss_contrib: 10.170372915134157
# X=[3 4], theta=
# [[ 2.75724051  2.71268947]
#  [-2.72981261 -2.68627897]]
# exp_term:
# [0.07082602 0.07375198]
# sum_exp: 0.14457799416553302
# log_sum: -1.933936165032763
# X=[3 4], class=1
# theta_c:
# [-2.72981261 -2.68627897]
# loss_contrib: -17.000617517885935
# Total loss: -6.830244602751778
# Iteration 27
# Loss: -6.8302
# Gradient:
# [[-0.9609907  -0.94123181]
#  [ 0.9609907   0.94123181]]
# Updated theta:
# [[ 2.75724051  2.71268947]
#  [-2.72981261 -2.68627897]]
# X=[1 2]
# exp_theta:
# [0.06704544 0.06995742]
# sum_exp_theta: 0.13700286170753487
# prob:
# [0.48937254 0.51062746]
# Class 0
# indicator: 1
# grad_contrib:
# [0.51062746 1.02125492]
# grad[0] after update:
# [0.51062746 1.02125492]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.51062746 -1.02125492]
# grad[1] after update:
# [-0.51062746 -1.02125492]
# X=[3 4]
# exp_theta:
# [0.07082602 0.07375198]
# sum_exp_theta: 0.14457799416553302
# prob:
# [0.48988102 0.51011898]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.46964306 -1.95952409]
# grad[0] after update:
# [-0.95901561 -0.93826917]
# Class 1
# indicator: 1
# grad_contrib:
# [1.46964306 1.95952409]
# grad[1] after update:
# [0.95901561 0.93826917]
# Gradient:
# [[-0.95901561 -0.93826917]
#  [ 0.95901561  0.93826917]]
# X=[1 2], theta=
# [[ 2.85314207  2.80651639]
#  [-2.82571417 -2.78010588]]
# exp_term:
# [0.06091436 0.06369206]
# sum_exp: 0.1246064239099467
# log_sum: -2.0825951176981583
# X=[1 2], class=0
# theta_c:
# [2.85314207 2.80651639]
# loss_contrib: 10.548769961939692
# X=[3 4], theta=
# [[ 2.85314207  2.80651639]
#  [-2.82571417 -2.78010588]]
# exp_term:
# [0.06434922 0.06714678]
# sum_exp: 0.13149599650877314
# log_sum: -2.0287788726279743
# X=[3 4], class=1
# theta_c:
# [-2.82571417 -2.78010588]
# loss_contrib: -17.56878715903875
# Total loss: -7.020017197099056
# Iteration 28
# Loss: -7.0200
# Gradient:
# [[-0.95901561 -0.93826917]
#  [ 0.95901561  0.93826917]]
# Updated theta:
# [[ 2.85314207  2.80651639]
#  [-2.82571417 -2.78010588]]
# X=[1 2]
# exp_theta:
# [0.06091436 0.06369206]
# sum_exp_theta: 0.1246064239099467
# prob:
# [0.48885413 0.51114587]
# Class 0
# indicator: 1
# grad_contrib:
# [0.51114587 1.02229175]
# grad[0] after update:
# [0.51114587 1.02229175]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.51114587 -1.02229175]
# grad[1] after update:
# [-0.51114587 -1.02229175]
# X=[3 4]
# exp_theta:
# [0.06434922 0.06714678]
# sum_exp_theta: 0.13149599650877314
# prob:
# [0.48936258 0.51063742]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.46808775 -1.95745034]
# grad[0] after update:
# [-0.95694188 -0.93515859]
# Class 1
# indicator: 1
# grad_contrib:
# [1.46808775 1.95745034]
# grad[1] after update:
# [0.95694188 0.93515859]
# Gradient:
# [[-0.95694188 -0.93515859]
#  [ 0.95694188  0.93515859]]
# X=[1 2], theta=
# [[ 2.94883626  2.90003225]
#  [-2.92140835 -2.87362174]]
# exp_term:
# [0.05535543 0.05800586]
# sum_exp: 0.11336129399042727
# log_sum: -2.177175268788121
# X=[1 2], class=0
# theta_c:
# [2.94883626 2.90003225]
# loss_contrib: 10.926076018445281
# X=[3 4], theta=
# [[ 2.94883626  2.90003225]
#  [-2.92140835 -2.87362174]]
# exp_term:
# [0.05847683 0.06115215]
# sum_exp: 0.11962898333102491
# log_sum: -2.123360131280434
# X=[3 4], class=1
# theta_c:
# [-2.92140835 -2.87362174]
# loss_contrib: -18.135351899026062
# Total loss: -7.2092758805807815
# Iteration 29
# Loss: -7.2093
# Gradient:
# [[-0.95694188 -0.93515859]
#  [ 0.95694188  0.93515859]]
# Updated theta:
# [[ 2.94883626  2.90003225]
#  [-2.92140835 -2.87362174]]
# X=[1 2]
# exp_theta:
# [0.05535543 0.05800586]
# sum_exp_theta: 0.11336129399042727
# prob:
# [0.48830983 0.51169017]
# Class 0
# indicator: 1
# grad_contrib:
# [0.51169017 1.02338034]
# grad[0] after update:
# [0.51169017 1.02338034]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.51169017 -1.02338034]
# grad[1] after update:
# [-0.51169017 -1.02338034]
# X=[3 4]
# exp_theta:
# [0.05847683 0.06115215]
# sum_exp_theta: 0.11962898333102491
# prob:
# [0.48881826 0.51118174]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.46645478 -1.95527304]
# grad[0] after update:
# [-0.95476461 -0.9318927 ]
# Class 1
# indicator: 1
# grad_contrib:
# [1.46645478 1.95527304]
# grad[1] after update:
# [0.95476461 0.9318927 ]
# Gradient:
# [[-0.95476461 -0.9318927 ]
#  [ 0.95476461  0.9318927 ]]
# X=[1 2], theta=
# [[ 3.04431272  2.99322152]
#  [-3.01688482 -2.96681101]]
# exp_term:
# [0.05031475 0.05284456]
# sum_exp: 0.10315931448627937
# log_sum: -2.2714807431415243
# X=[1 2], class=0
# theta_c:
# [3.04431272 2.99322152]
# loss_contrib: 11.302236493882791
# X=[3 4], theta=
# [[ 3.04431272  2.99322152]
#  [-3.01688482 -2.96681101]]
# exp_term:
# [0.05315192 0.0557109 ]
# sum_exp: 0.10886281488261093
# log_sum: -2.2176667684873985
# X=[3 4], class=1
# theta_c:
# [-3.01688482 -2.96681101]
# loss_contrib: -18.700231725094724
# Total loss: -7.397995231211933
# Iteration 30
# Loss: -7.3980
# Gradient:
# [[-0.95476461 -0.9318927 ]
#  [ 0.95476461  0.9318927 ]]
# Updated theta:
# [[ 3.04431272  2.99322152]
#  [-3.01688482 -2.96681101]]
# X=[1 2]
# exp_theta:
# [0.05031475 0.05284456]
# sum_exp_theta: 0.10315931448627937
# prob:
# [0.48773836 0.51226164]
# Class 0
# indicator: 1
# grad_contrib:
# [0.51226164 1.02452328]
# grad[0] after update:
# [0.51226164 1.02452328]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.51226164 -1.02452328]
# grad[1] after update:
# [-0.51226164 -1.02452328]
# X=[3 4]
# exp_theta:
# [0.05315192 0.0557109 ]
# sum_exp_theta: 0.10886281488261093
# prob:
# [0.48824676 0.51175324]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.46474029 -1.95298706]
# grad[0] after update:
# [-0.95247865 -0.92846377]
# Class 1
# indicator: 1
# grad_contrib:
# [1.46474029 1.95298706]
# grad[1] after update:
# [0.95247865 0.92846377]
# Gradient:
# [[-0.95247865 -0.92846377]
#  [ 0.95247865  0.92846377]]
# X=[1 2], theta=
# [[ 3.13956058  3.08606789]
#  [-3.11213268 -3.05965739]]
# exp_term:
# [0.04574354 0.04815902]
# sum_exp: 0.09390255365367663
# log_sum: -2.3654976976778945
# X=[1 2], class=0
# theta_c:
# [3.13956058 3.08606789]
# loss_contrib: 11.677194068023034
# X=[3 4], theta=
# [[ 3.13956058  3.08606789]
#  [-3.11213268 -3.05965739]]
# exp_term:
# [0.04832294 0.05077121]
# sum_exp: 0.09909414274144329
# log_sum: -2.3116849439192397
# X=[3 4], class=1
# theta_c:
# [-3.11213268 -3.05965739]
# loss_contrib: -19.26334265392645
# Total loss: -7.586148585903416
# Iteration 31
# Loss: -7.5861
# Gradient:
# [[-0.95247865 -0.92846377]
#  [ 0.95247865  0.92846377]]
# Updated theta:
# [[ 3.13956058  3.08606789]
#  [-3.11213268 -3.05965739]]
# X=[1 2]
# exp_theta:
# [0.04574354 0.04815902]
# sum_exp_theta: 0.09390255365367663
# prob:
# [0.48713837 0.51286163]
# Class 0
# indicator: 1
# grad_contrib:
# [0.51286163 1.02572327]
# grad[0] after update:
# [0.51286163 1.02572327]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.51286163 -1.02572327]
# grad[1] after update:
# [-0.51286163 -1.02572327]
# X=[3 4]
# exp_theta:
# [0.04832294 0.05077121]
# sum_exp_theta: 0.09909414274144329
# prob:
# [0.48764674 0.51235326]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.46294022 -1.95058696]
# grad[0] after update:
# [-0.95007859 -0.92486369]
# Class 1
# indicator: 1
# grad_contrib:
# [1.46294022 1.95058696]
# grad[1] after update:
# [0.95007859 0.92486369]
# Gradient:
# [[-0.95007859 -0.92486369]
#  [ 0.95007859  0.92486369]]
# X=[1 2], theta=
# [[ 3.23456844  3.17855426]
#  [-3.20714054 -3.15214376]]
# exp_term:
# [0.04159761 0.04390473]
# sum_exp: 0.08550233553720527
# log_sum: -2.459211587187881
# X=[1 2], class=0
# theta_c:
# [3.23456844 3.17855426]
# loss_contrib: 12.050888555389815
# X=[3 4], theta=
# [[ 3.23456844  3.17855426]
#  [-3.20714054 -3.15214376]]
# exp_term:
# [0.04394322 0.04628616]
# sum_exp: 0.09022938623262382
# log_sum: -2.405400115252838
# X=[3 4], class=1
# theta_c:
# [-3.20714054 -3.15214376]
# loss_contrib: -19.824596537174187
# Total loss: -7.773707981784373
# Iteration 32
# Loss: -7.7737
# Gradient:
# [[-0.95007859 -0.92486369]
#  [ 0.95007859  0.92486369]]
# Updated theta:
# [[ 3.23456844  3.17855426]
#  [-3.20714054 -3.15214376]]
# X=[1 2]
# exp_theta:
# [0.04159761 0.04390473]
# sum_exp_theta: 0.08550233553720527
# prob:
# [0.48650843 0.51349157]
# Class 0
# indicator: 1
# grad_contrib:
# [0.51349157 1.02698314]
# grad[0] after update:
# [0.51349157 1.02698314]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.51349157 -1.02698314]
# grad[1] after update:
# [-0.51349157 -1.02698314]
# X=[3 4]
# exp_theta:
# [0.04394322 0.04628616]
# sum_exp_theta: 0.09022938623262382
# prob:
# [0.48701677 0.51298323]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.46105032 -1.94806709]
# grad[0] after update:
# [-0.94755875 -0.92108396]
# Class 1
# indicator: 1
# grad_contrib:
# [1.46105032 1.94806709]
# grad[1] after update:
# [0.94755875 0.92108396]
# Gradient:
# [[-0.94755875 -0.92108396]
#  [ 0.94755875  0.92108396]]
# X=[1 2], theta=
# [[ 3.32932432  3.27066266]
#  [-3.30189641 -3.24425215]]
# exp_term:
# [0.03783697 0.04004139]
# sum_exp: 0.07787836220696567
# log_sum: -2.5526071283992438
# X=[1 2], class=0
# theta_c:
# [3.32932432 3.27066266]
# loss_contrib: 12.42325676286213
# X=[3 4], theta=
# [[ 3.32932432  3.27066266]
#  [-3.30189641 -3.24425215]]
# exp_term:
# [0.03997054 0.04221327]
# sum_exp: 0.08218380611372281
# log_sum: -2.498797002243998
# X=[3 4], class=1
# theta_c:
# [-3.30189641 -3.24425215]
# loss_contrib: -20.38390085784551
# Total loss: -7.960644094983381
# Iteration 33
# Loss: -7.9606
# Gradient:
# [[-0.94755875 -0.92108396]
#  [ 0.94755875  0.92108396]]
# Updated theta:
# [[ 3.32932432  3.27066266]
#  [-3.30189641 -3.24425215]]
# X=[1 2]
# exp_theta:
# [0.03783697 0.04004139]
# sum_exp_theta: 0.07787836220696567
# prob:
# [0.48584707 0.51415293]
# Class 0
# indicator: 1
# grad_contrib:
# [0.51415293 1.02830587]
# grad[0] after update:
# [0.51415293 1.02830587]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.51415293 -1.02830587]
# grad[1] after update:
# [-0.51415293 -1.02830587]
# X=[3 4]
# exp_theta:
# [0.03997054 0.04221327]
# sum_exp_theta: 0.08218380611372281
# prob:
# [0.48635537 0.51364463]
# Class 0
# indicator: 0
# grad_contrib:
# [-1.45906612 -1.94542149]
# grad[0] after update:
# [-0.94491319 -0.91711563]
# Class 1
# indicator: 1
# grad_contrib:
# [1.45906612 1.94542149]
# grad[1] after update:
# [0.94491319 0.91711563]
# Gradient:
# [[-0.94491319 -0.91711563]
# ...
# loss_contrib: 26.600113083061395
# X=[3 4], theta=
# [[ 7.35445646  6.55699998]
#  [-7.32702855 -6.53058948]]
# exp_term:
# [0.00071392 0.00157838]
# sum_exp: 0.002292293623417775
# log_sum: -6.078202380386348
# X=[3 4], class=1
# theta_c:
# [-7.32702855 -6.53058948]
# loss_contrib: -42.02524118341565
# Total loss: -15.425128100354257
# Iteration 88
# Loss: -15.4251
# Gradient:
# [[-0.27658123  0.08534918]
#  [ 0.27658123 -0.08534918]]
# Updated theta:
# [[ 7.35445646  6.55699998]
#  [-7.32702855 -6.53058948]]
# X=[1 2]
# exp_theta:
# [0.00067581 0.00149717]
# sum_exp_theta: 0.0021729780777992387
# prob:
# [0.31100572 0.68899428]
# Class 0
# indicator: 1
# grad_contrib:
# [0.68899428 1.37798857]
# grad[0] after update:
# [0.68899428 1.37798857]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.68899428 -1.37798857]
# grad[1] after update:
# [-0.68899428 -1.37798857]
# X=[3 4]
# exp_theta:
# [0.00071392 0.00157838]
# sum_exp_theta: 0.002292293623417775
# prob:
# [0.3114419 0.6885581]
# Class 0
# indicator: 0
# grad_contrib:
# [-0.93432571 -1.24576762]
# grad[0] after update:
# [-0.24533143  0.13222095]
# Class 1
# indicator: 1
# grad_contrib:
# [0.93432571 1.24576762]
# grad[1] after update:
# [ 0.24533143 -0.13222095]
# Gradient:
# [[-0.24533143  0.13222095]
#  [ 0.24533143 -0.13222095]]
# X=[1 2], theta=
# [[ 7.3789896   6.54377789]
#  [-7.3515617  -6.51736738]]
# exp_term:
# [0.00065943 0.0015171 ]
# sum_exp: 0.002176527258050605
# log_sum: -6.130024673250388
# X=[1 2], class=0
# theta_c:
# [7.3789896  6.54377789]
# loss_contrib: 26.596570042946468
# X=[3 4], theta=
# [[ 7.3789896   6.54377789]
#  [-7.3515617  -6.51736738]]
# exp_term:
# [0.00069661 0.00159939]
# sum_exp: 0.002296000145201399
# log_sum: -6.076586737283792
# X=[3 4], class=1
# theta_c:
# [-7.3515617  -6.51736738]
# loss_contrib: -42.04756787507893
# Total loss: -15.450997832132465
# Iteration 89
# Loss: -15.4510
# Gradient:
# [[-0.24533143  0.13222095]
#  [ 0.24533143 -0.13222095]]
# Updated theta:
# [[ 7.3789896   6.54377789]
#  [-7.3515617  -6.51736738]]
# X=[1 2]
# exp_theta:
# [0.00065943 0.0015171 ]
# sum_exp_theta: 0.002176527258050605
# prob:
# [0.30297375 0.69702625]
# Class 0
# indicator: 1
# grad_contrib:
# [0.69702625 1.39405251]
# grad[0] after update:
# [0.69702625 1.39405251]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.69702625 -1.39405251]
# grad[1] after update:
# [-0.69702625 -1.39405251]
# X=[3 4]
# exp_theta:
# [0.00069661 0.00159939]
# sum_exp_theta: 0.002296000145201399
# prob:
# [0.30340363 0.69659637]
# Class 0
# indicator: 0
# grad_contrib:
# [-0.91021089 -1.21361452]
# grad[0] after update:
# [-0.21318464  0.18043799]
# Class 1
# indicator: 1
# grad_contrib:
# [0.91021089 1.21361452]
# grad[1] after update:
# [ 0.21318464 -0.18043799]
# Gradient:
# [[-0.21318464  0.18043799]
#  [ 0.21318464 -0.18043799]]
# X=[1 2], theta=
# [[ 7.40030806  6.52573409]
#  [-7.37288016 -6.49932358]]
# exp_term:
# [0.00064552 0.00154472]
# sum_exp: 0.0021902406446690833
# log_sum: -6.123743857779927
# X=[1 2], class=0
# theta_c:
# [7.40030806 6.52573409]
# loss_contrib: 26.575520093880236
# X=[3 4], theta=
# [[ 7.40030806  6.52573409]
#  [-7.37288016 -6.49932358]]
# exp_term:
# [0.00068192 0.00162851]
# sum_exp: 0.0023104274905600885
# log_sum: -6.070322710721558
# X=[3 4], class=1
# theta_c:
# [-7.37288016 -6.49932358]
# loss_contrib: -42.04561209810734
# Total loss: -15.470092004227105
# Iteration 90
# Loss: -15.4701
# Gradient:
# [[-0.21318464  0.18043799]
#  [ 0.21318464 -0.18043799]]
# Updated theta:
# [[ 7.40030806  6.52573409]
#  [-7.37288016 -6.49932358]]
# X=[1 2]
# exp_theta:
# [0.00064552 0.00154472]
# sum_exp_theta: 0.0021902406446690833
# prob:
# [0.29472623 0.70527377]
# Class 0
# indicator: 1
# grad_contrib:
# [0.70527377 1.41054755]
# grad[0] after update:
# [0.70527377 1.41054755]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.70527377 -1.41054755]
# grad[1] after update:
# [-0.70527377 -1.41054755]
# X=[3 4]
# exp_theta:
# [0.00068192 0.00162851]
# sum_exp_theta: 0.0023104274905600885
# prob:
# [0.29514936 0.70485064]
# Class 0
# indicator: 0
# grad_contrib:
# [-0.88544809 -1.18059745]
# grad[0] after update:
# [-0.18017431  0.2299501 ]
# Class 1
# indicator: 1
# grad_contrib:
# [0.88544809 1.18059745]
# grad[1] after update:
# [ 0.18017431 -0.2299501 ]
# Gradient:
# [[-0.18017431  0.2299501 ]
#  [ 0.18017431 -0.2299501 ]]
# X=[1 2], theta=
# [[ 7.41832549  6.50273908]
#  [-7.39089759 -6.47632857]]
# exp_term:
# [0.00063399 0.00158065]
# sum_exp: 0.0022146465431608377
# log_sum: -6.112662462412107
# X=[1 2], class=0
# theta_c:
# [7.41832549 6.50273908]
# loss_contrib: 26.53646611008888
# X=[3 4], theta=
# [[ 7.41832549  6.50273908]
#  [-7.39089759 -6.47632857]]
# exp_term:
# [0.00066974 0.00166639]
# sum_exp: 0.002336132436206895
# log_sum: -6.059258522041458
# X=[3 4], class=1
# theta_c:
# [-7.39089759 -6.47632857]
# loss_contrib: -42.0187485412157
# Total loss: -15.48228243112682
# Iteration 91
# Loss: -15.4823
# Gradient:
# [[-0.18017431  0.2299501 ]
#  [ 0.18017431 -0.2299501 ]]
# Updated theta:
# [[ 7.41832549  6.50273908]
#  [-7.39089759 -6.47632857]]
# X=[1 2]
# exp_theta:
# [0.00063399 0.00158065]
# sum_exp_theta: 0.0022146465431608377
# prob:
# [0.28627362 0.71372638]
# Class 0
# indicator: 1
# grad_contrib:
# [0.71372638 1.42745277]
# grad[0] after update:
# [0.71372638 1.42745277]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.71372638 -1.42745277]
# grad[1] after update:
# [-0.71372638 -1.42745277]
# X=[3 4]
# exp_theta:
# [0.00066974 0.00166639]
# sum_exp_theta: 0.002336132436206895
# prob:
# [0.28668955 0.71331045]
# Class 0
# indicator: 0
# grad_contrib:
# [-0.86006865 -1.1467582 ]
# grad[0] after update:
# [-0.14634226  0.28069457]
# Class 1
# indicator: 1
# grad_contrib:
# [0.86006865 1.1467582 ]
# grad[1] after update:
# [ 0.14634226 -0.28069457]
# Gradient:
# [[-0.14634226  0.28069457]
#  [ 0.14634226 -0.28069457]]
# X=[1 2], theta=
# [[ 7.43295972  6.47466962]
#  [-7.40553182 -6.44825912]]
# exp_term:
# [0.00062478 0.00162565]
# sum_exp: 0.002250432671824731
# log_sum: -6.0966327826640425
# X=[1 2], class=0
# theta_c:
# [7.43295972 6.47466962]
# loss_contrib: 26.478931742598967
# X=[3 4], theta=
# [[ 7.43295972  6.47466962]
#  [-7.40553182 -6.44825912]]
# exp_term:
# [0.00066001 0.00171382]
# sum_exp: 0.0023738398595774166
# log_sum: -6.043246441018772
# X=[3 4], class=1
# theta_c:
# [-7.40553182 -6.44825912]
# loss_contrib: -41.9663854731408
# Total loss: -15.48745373054183
# Iteration 92
# Loss: -15.4875
# Gradient:
# [[-0.14634226  0.28069457]
#  [ 0.14634226 -0.28069457]]
# Updated theta:
# [[ 7.43295972  6.47466962]
#  [-7.40553182 -6.44825912]]
# X=[1 2]
# exp_theta:
# [0.00062478 0.00162565]
# sum_exp_theta: 0.002250432671824731
# prob:
# [0.27762857 0.72237143]
# Class 0
# indicator: 1
# grad_contrib:
# [0.72237143 1.44474286]
# grad[0] after update:
# [0.72237143 1.44474286]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.72237143 -1.44474286]
# grad[1] after update:
# [-0.72237143 -1.44474286]
# X=[3 4]
# exp_theta:
# [0.00066001 0.00171382]
# sum_exp_theta: 0.0023738398595774166
# prob:
# [0.27803684 0.72196316]
# Class 0
# indicator: 0
# grad_contrib:
# [-0.83411051 -1.11214735]
# grad[0] after update:
# [-0.11173908  0.33259551]
# Class 1
# indicator: 1
# grad_contrib:
# [0.83411051 1.11214735]
# grad[1] after update:
# [ 0.11173908 -0.33259551]
# Gradient:
# [[-0.11173908  0.33259551]
#  [ 0.11173908 -0.33259551]]
# X=[1 2], theta=
# [[ 7.44413363  6.44141007]
#  [-7.41670573 -6.41499956]]
# exp_term:
# [0.00061784 0.00168063]
# sum_exp: 0.002298467774314934
# log_sum: -6.075512563127378
# X=[1 2], class=0
# theta_c:
# [7.44413363 6.44141007]
# loss_contrib: 26.40246632985564
# X=[3 4], theta=
# [[ 7.44413363  6.44141007]
#  [-7.41670573 -6.41499956]]
# exp_term:
# [0.00065268 0.00177178]
# sum_exp: 0.002424465522761217
# log_sum: -6.022144181870063
# X=[3 4], class=1
# theta_c:
# [-7.41670573 -6.41499956]
# loss_contrib: -41.88797125420824
# Total loss: -15.4855049243526
# Iteration 93
# Loss: -15.4855
# Gradient:
# [[-0.11173908  0.33259551]
#  [ 0.11173908 -0.33259551]]
# Updated theta:
# [[ 7.44413363  6.44141007]
#  [-7.41670573 -6.41499956]]
# X=[1 2]
# exp_theta:
# [0.00061784 0.00168063]
# sum_exp_theta: 0.002298467774314934
# prob:
# [0.26880602 0.73119398]
# Class 0
# indicator: 1
# grad_contrib:
# [0.73119398 1.46238795]
# grad[0] after update:
# [0.73119398 1.46238795]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.73119398 -1.46238795]
# grad[1] after update:
# [-0.73119398 -1.46238795]
# X=[3 4]
# exp_theta:
# [0.00065268 0.00177178]
# sum_exp_theta: 0.002424465522761217
# prob:
# [0.26920615 0.73079385]
# Class 0
# indicator: 0
# grad_contrib:
# [-0.80761845 -1.0768246 ]
# grad[0] after update:
# [-0.07642448  0.38556335]
# Class 1
# indicator: 1
# grad_contrib:
# [0.80761845 1.0768246 ]
# grad[1] after update:
# [ 0.07642448 -0.38556335]
# Gradient:
# [[-0.07642448  0.38556335]
#  [ 0.07642448 -0.38556335]]
# X=[1 2], theta=
# [[ 7.45177608  6.40285373]
#  [-7.42434817 -6.37644323]]
# exp_term:
# [0.00061314 0.00174669]
# sum_exp: 0.0023598281298187313
# log_sum: -6.04916648894458
# X=[1 2], class=0
# theta_c:
# [7.45177608 6.40285373]
# loss_contrib: 26.306650033443105
# X=[3 4], theta=
# [[ 7.45177608  6.40285373]
#  [-7.42434817 -6.37644323]]
# exp_term:
# [0.00064771 0.00184143]
# sum_exp: 0.002489144020098598
# log_sum: -5.995816394635626
# X=[3 4], class=1
# theta_c:
# [-7.42434817 -6.37644323]
# loss_contrib: -41.78300104458574
# Total loss: -15.476351011142633
# Iteration 94
# Loss: -15.4764
# Gradient:
# [[-0.07642448  0.38556335]
#  [ 0.07642448 -0.38556335]]
# Updated theta:
# [[ 7.45177608  6.40285373]
#  [-7.42434817 -6.37644323]]
# X=[1 2]
# exp_theta:
# [0.00061314 0.00174669]
# sum_exp_theta: 0.0023598281298187313
# prob:
# [0.25982323 0.74017677]
# Class 0
# indicator: 1
# grad_contrib:
# [0.74017677 1.48035355]
# grad[0] after update:
# [0.74017677 1.48035355]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.74017677 -1.48035355]
# grad[1] after update:
# [-0.74017677 -1.48035355]
# X=[3 4]
# exp_theta:
# [0.00064771 0.00184143]
# sum_exp_theta: 0.002489144020098598
# prob:
# [0.26021474 0.73978526]
# Class 0
# indicator: 0
# grad_contrib:
# [-0.78064422 -1.04085896]
# grad[0] after update:
# [-0.04046744  0.43949459]
# Class 1
# indicator: 1
# grad_contrib:
# [0.78064422 1.04085896]
# grad[1] after update:
# [ 0.04046744 -0.43949459]
# Gradient:
# [[-0.04046744  0.43949459]
#  [ 0.04046744 -0.43949459]]
# X=[1 2], theta=
# [[ 7.45582282  6.35890427]
#  [-7.42839492 -6.33249377]]
# exp_term:
# [0.00061066 0.00182517]
# sum_exp: 0.0024358299105549782
# log_sum: -6.017467754825536
# X=[1 2], class=0
# theta_c:
# [7.45582282 6.35890427]
# loss_contrib: 26.191099125300298
# X=[3 4], theta=
# [[ 7.45582282  6.35890427]
#  [-7.42839492 -6.33249377]]
# exp_term:
# [0.0006451  0.00192417]
# sum_exp: 0.0025692628906568175
# log_sum: -5.964136234187717
# X=[3 4], class=1
# theta_c:
# [-7.42839492 -6.33249377]
# loss_contrib: -41.651023601322784
# Total loss: -15.459924476022486
# Iteration 95
# Loss: -15.4599
# Gradient:
# [[-0.04046744  0.43949459]
#  [ 0.04046744 -0.43949459]]
# Updated theta:
# [[ 7.45582282  6.35890427]
#  [-7.42839492 -6.33249377]]
# X=[1 2]
# exp_theta:
# [0.00061066 0.00182517]
# sum_exp_theta: 0.0024358299105549782
# prob:
# [0.25069975 0.74930025]
# Class 0
# indicator: 1
# grad_contrib:
# [0.74930025 1.49860049]
# grad[0] after update:
# [0.74930025 1.49860049]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.74930025 -1.49860049]
# grad[1] after update:
# [-0.74930025 -1.49860049]
# X=[3 4]
# exp_theta:
# [0.0006451  0.00192417]
# sum_exp_theta: 0.0025692628906568175
# prob:
# [0.25108218 0.74891782]
# Class 0
# indicator: 0
# grad_contrib:
# [-0.75324655 -1.00432873]
# grad[0] after update:
# [-0.0039463   0.49427176]
# Class 1
# indicator: 1
# grad_contrib:
# [0.75324655 1.00432873]
# grad[1] after update:
# [ 0.0039463  -0.49427176]
# Gradient:
# [[-0.0039463   0.49427176]
#  [ 0.0039463  -0.49427176]]
# X=[1 2], theta=
# [[ 7.45621745  6.3094771 ]
#  [-7.42878955 -6.28306659]]
# exp_term:
# [0.00061042 0.00191765]
# sum_exp: 0.0025280685462573805
# log_sum: -5.980299688248124
# X=[1 2], class=0
# theta_c:
# [7.45621745 6.3094771 ]
# loss_contrib: 26.055471335867924
# X=[3 4], theta=
# [[ 7.45621745  6.3094771 ]
#  [-7.42878955 -6.28306659]]
# exp_term:
# [0.00064484 0.00202166]
# sum_exp: 0.002666504118150662
# log_sum: -5.926986983521786
# X=[3 4], class=1
# theta_c:
# [-7.42878955 -6.28306659]
# loss_contrib: -41.491648036302706
# Total loss: -15.436176700434782
# Iteration 96
# Loss: -15.4362
# Gradient:
# [[-0.0039463   0.49427176]
#  [ 0.0039463  -0.49427176]]
# Updated theta:
# [[ 7.45621745  6.3094771 ]
#  [-7.42878955 -6.28306659]]
# X=[1 2]
# exp_theta:
# [0.00061042 0.00191765]
# sum_exp_theta: 0.0025280685462573805
# prob:
# [0.24145746 0.75854254]
# Class 0
# indicator: 1
# grad_contrib:
# [0.75854254 1.51708507]
# grad[0] after update:
# [0.75854254 1.51708507]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.75854254 -1.51708507]
# grad[1] after update:
# [-0.75854254 -1.51708507]
# X=[3 4]
# exp_theta:
# [0.00064484 0.00202166]
# sum_exp_theta: 0.002666504118150662
# prob:
# [0.24183034 0.75816966]
# Class 0
# indicator: 0
# grad_contrib:
# [-0.72549103 -0.96732138]
# grad[0] after update:
# [0.0330515  0.54976369]
# Class 1
# indicator: 1
# grad_contrib:
# [0.72549103 0.96732138]
# grad[1] after update:
# [-0.0330515  -0.54976369]
# Gradient:
# [[ 0.0330515   0.54976369]
#  [-0.0330515  -0.54976369]]
# X=[1 2], theta=
# [[ 7.4529123   6.25450073]
#  [-7.4254844  -6.22809022]]
# exp_term:
# [0.00061244 0.00202602]
# sum_exp: 0.0026384665105670746
# log_sum: -5.9375573978020695
# X=[1 2], class=0
# theta_c:
# [7.4529123  6.25450073]
# loss_contrib: 25.899471156232895
# X=[3 4], theta=
# [[ 7.4529123   6.25450073]
#  [-7.4254844  -6.22809022]]
# exp_term:
# [0.00064698 0.00213592]
# sum_exp: 0.002782894509981401
# log_sum: -5.8842637023018245
# X=[3 4], class=1
# theta_c:
# [-7.4254844  -6.22809022]
# loss_contrib: -41.30455038887466
# Total loss: -15.405079232641764
# Iteration 97
# Loss: -15.4051
# Gradient:
# [[ 0.0330515   0.54976369]
#  [-0.0330515  -0.54976369]]
# Updated theta:
# [[ 7.4529123   6.25450073]
#  [-7.4254844  -6.22809022]]
# X=[1 2]
# exp_theta:
# [0.00061244 0.00202602]
# sum_exp_theta: 0.0026384665105670746
# prob:
# [0.2321204 0.7678796]
# Class 0
# indicator: 1
# grad_contrib:
# [0.7678796  1.53575921]
# grad[0] after update:
# [0.7678796  1.53575921]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.7678796  -1.53575921]
# grad[1] after update:
# [-0.7678796  -1.53575921]
# X=[3 4]
# exp_theta:
# [0.00064698 0.00213592]
# sum_exp_theta: 0.002782894509981401
# prob:
# [0.23248328 0.76751672]
# Class 0
# indicator: 0
# grad_contrib:
# [-0.69744983 -0.92993311]
# grad[0] after update:
# [0.07042977 0.6058261 ]
# Class 1
# indicator: 1
# grad_contrib:
# [0.69744983 0.92993311]
# grad[1] after update:
# [-0.07042977 -0.6058261 ]
# Gradient:
# [[ 0.07042977  0.6058261 ]
#  [-0.07042977 -0.6058261 ]]
# X=[1 2], theta=
# [[ 7.44586932  6.19391812]
#  [-7.41844142 -6.16750761]]
# exp_term:
# [0.00061677 0.00215256]
# sum_exp: 0.0027693312548411103
# log_sum: -5.889149412175501
# X=[1 2], class=0
# theta_c:
# [7.44586932 6.19391812]
# loss_contrib: 25.722854972612694
# X=[3 4], theta=
# [[ 7.44586932  6.19391812]
#  [-7.41844142 -6.16750761]]
# exp_term:
# [0.00065155 0.00226932]
# sum_exp: 0.0029208667745001643
# log_sum: -5.835874866168147
# X=[3 4], class=1
# theta_c:
# [-7.41844142 -6.16750761]
# loss_contrib: -41.089479851552746
# Total loss: -15.366624878940051
# Iteration 98
# Loss: -15.3666
# Gradient:
# [[ 0.07042977  0.6058261 ]
#  [-0.07042977 -0.6058261 ]]
# Updated theta:
# [[ 7.44586932  6.19391812]
#  [-7.41844142 -6.16750761]]
# X=[1 2]
# exp_theta:
# [0.00061677 0.00215256]
# sum_exp_theta: 0.0027693312548411103
# prob:
# [0.22271461 0.77728539]
# Class 0
# indicator: 1
# grad_contrib:
# [0.77728539 1.55457078]
# grad[0] after update:
# [0.77728539 1.55457078]
# Class 1
# indicator: 0
# grad_contrib:
# [-0.77728539 -1.55457078]
# grad[1] after update:
# [-0.77728539 -1.55457078]
# X=[3 4]
# exp_theta:
# [0.00065155 0.00226932]
# sum_exp_theta: 0.0029208667745001643
# prob:
# [0.22306706 0.77693294]
# Class 0
# indicator: 0
# grad_contrib:
# [-0.66920117 -0.89226823]
# grad[0] after update:
# [0.10808422 0.66230255]
# Class 1
# indicator: 1
# grad_contrib:
# [0.66920117 0.89226823]
# grad[1] after update:
# [-0.10808422 -0.66230255]
# Gradient:
# [[ 0.10808422  0.66230255]
#  [-0.10808422 -0.66230255]]
# X=[1 2], theta=
# [[ 7.4350609   6.12768786]
#  [-7.407633   -6.10127736]]
# exp_term:
# [0.00062347 0.00229995]
# sum_exp: 0.002923425393007389
# log_sum: -5.834999270425375
# X=[1 2], class=0
# theta_c:
# [7.4350609  6.12768786]
# loss_contrib: 25.525435899640513
# X=[3 4], theta=
# [[ 7.4350609   6.12768786]
#  [-7.407633   -6.10127736]]
# exp_term:
# [0.00065863 0.0024247 ]
# sum_exp: 0.003083333514239062
# log_sum: -5.781743957453786
# X=[3 4], class=1
# theta_c:
# [-7.407633   -6.10127736]
# loss_contrib: -40.84626447622796
# Total loss: -15.320828576587445
# Iteration 99
# Loss: -15.3208
# Gradient:
# [[ 0.10808422  0.66230255]
#  [-0.10808422 -0.66230255]]
# Updated theta:
# [[ 7.4350609   6.12768786]
#  [-7.407633   -6.10127736]]
# Final Parameters:
#  [[ 7.4350609   6.12768786]
#  [-7.407633   -6.10127736]]
